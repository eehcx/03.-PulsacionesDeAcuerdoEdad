# %%
#CALCULAREMOS EL NUMERO DE PULSACIONES DE ACUERDO A TU EDAD
Edad = int(input("Escribe tu edad"))
print(Edad)
# Out:
# 18

# %%
#VARIABLES
Genero = int(input("Escribe un número de acuerdo a tu genero"))
print(Genero)
print("1 = Masculino")
print("2 = Femenino")

#FUNCIÓN
if Genero == 1:
  NumeroPulsaciones = (220-Edad)/10
elif Genero == 2:
  NumeroPulsaciones = (220-Edad)/10
else:
  print("Escribe un número correcto")


#TUS PULSACIONES
print("Las pulsaciones de acuerdo a tu edad son: " + str(NumeroPulsaciones))
# Out:
# 1
# 1 = Masculino
# 2 = Femenino
# Las pulsaciones de acuerdo a tu edad son: 20.2
